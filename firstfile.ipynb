# %%
x,y,z = "Apple","Banana","Cherry"

print(x)
print(y)
print(z)
# Out:
# Apple
# Banana
# Cherry

# %%
x=y=z="Ujjwal"
print(x)
print(y)
print(z)
# Out:
# Ujjwal
# Ujjwal
# Ujjwal

# %%
name = ["ujjwal","sahu"]
x,y = name
print(x)
print(y)
# Out:
# ujjwal
# sahu

# %%
x = "Super"

def myfun():
    print("Python is " + x)

myfun()
# Out:
# Python is Super

# %%
x = "Ujjwal"

def who():
    print(x + " wants to learn more about Data science...")

who()
# Out:
# Ujjwal wants to learn more about Data science...

# %%
x = "Machine Learning"

def myfunc():
    x = "Deep learning"
    print("Python helps in " + x)

myfunc()

print("Python helps in " + x)
# Out:
# Python helps in Deep learning
# Python helps in Machine Learning

# %%
# DATA TYPES-------------------------------
m = 10
print(type(m))
# Out:
# <class 'int'>

# %%
x = int(7)

y = int(80.2)

z = int("3")

print(x)
print(y)
print(z)
# Out:
# 7
# 80
# 3

# %%
x = str("7")

y = str(80.2)

z = str(3)

print(x)
print(y)
print(z)
# Out:
# 7
# 80.2
# 3

# %%
x = float("7")

y = float(80.2)

z = float(3)

print(x)
print(y)
print(z)
# Out:
# 7.0
# 80.2
# 3.0

# %%
u = "This is the first letter of my name..."
"But not my surname's first letter.."
print(u)
# Out:
# This is the first letter of my name...

# %%
u = "This is the first letter of my name...,  But not my surname's first letter.."
print(u)
# Out:
# This is the first letter of my name...,  But not my surname's first letter..

# %%
# PYTHON SLICING----------------------
# SLICING SYNTAX --- (start:stop:step)
u = "UjjwalSahu"
print(u[6:11])


p = "He is my best friend"
print(p[:13])
# Out:
# Sahu
# He is my best

# %%
a = 66
b = 33
c = 33

d = a + b

print("Add:",d+c)
print("Sub:",d-c)
print("Mul:",d*c)
print("Div:",d/c)
print("Rem:",d%c)
print("Pure DIV:",d//c)
# Out:
# Add: 132
# Sub: 66
# Mul: 3267
# Div: 3.0
# Rem: 0
# Pure DIV: 3

# %%
balance = 10000

balance += 9000

balance -= 8000

balance *= 2

print(balance)
# Out:
# 22000

# %%
a = 20

a -= 10

a *= 3

a //= 4

print(a)
# Out:
# 7

# %%
# COMPARISION OPEERATORS (==,!=,<,>,>=,<=)

a = 80
b = 80
print(a == b)
# Out:
# True

# %%
temp = 30

print(temp<35)
# Out:
# True

# %%
x = 20
y = 15

print(x>y)
print(x<y)
print(x==y)
# Out:
# True
# False
# False

# %%
# LOGICAL OPERATOR (and,or,not)

age = 20

has_license = True

print (age>=18 and has_license)
# Out:
# True

# %%
#IDENTITY OPERATOE IN PYTHON:- is,is not
a = [1,2,3]
a = [1,2,3]

print(a is a)

b = [1,2,3]
c = [1,2,3]

print(b is c)
# Out:
# True
# False

# %%
#membership operator-----
fruits = ["apple","banana"]

print("banana" not in fruits)
print("apple" in fruits)
# Out:
# False
# True

# %%
# BITWISE OPERATOR IN PYTHON (&,|,^,~,<<,>>)
a = 10
b = 6

print(a & b)
# Out:
# 2

# %%
# BITWISE OPERATOR IN PYTHON (&,|,^,~,<<,>>)
a = 10
b = 6

print(a | b)
# Out:
# 14

# %%
# BITWISE OPERATOR IN PYTHON (&,|,^,~,<<,>>)
a = 10
b = 6

print(a ^ b)
# Out:
# 12

# %%
# BITWISE OPERATOR IN PYTHON (&,|,^,~,<<,>>)
a = 10
b = 6

print(~(a & b))
# Out:
# -3

# %%
# LEFT SHIFT
a = 5

print(a<<1)
print(a<<2)
print(a<<3)
# Out:
# 10
# 20
# 40

# %%
# LEFT SHIFT
a = 5

print(a>>1)
print(a>>2)
print(a>>3)
# Out:
# 2
# 1
# 0
