# %%
#PATTERN PRINTING -----
# for i in range(1,6):
    for j in range(1,5):
        print("*", end=" ")
    print("*")
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
rows = 5
for i in range(1, rows + 1):
    print("* " * i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
